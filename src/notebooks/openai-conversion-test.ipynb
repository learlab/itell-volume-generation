# %% [markdown]
# # OpenAI PDF to iTELL JSON Conversion Test

# %%
import openai
import json
import requests
from dotenv import load_dotenv
import os
import base64
from pathlib import Path

# Load environment variables
load_dotenv()
client = openai.OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# File paths
pdf_path = "../data/input-docs/Civics Test Text-first-4-chapters.pdf"
example_output_path = "../data/reference-json/Civics Test Text iTELL JSON.json"
md_instructions_path = "../doc/guide-to-itell-json.md"
strapi_url = os.getenv("CMS_URL", "http://localhost:1337")
strapi_key = os.getenv("CMS_KEY")

# %%
# Load example JSON and instructions
with open(example_output_path, "r", encoding="utf-8") as f:
    example_json = json.load(f)

with open(md_instructions_path, "r", encoding="utf-8") as f:
    md_instructions = f.read()

with open(pdf_path, "rb") as f:
    pdf_b64 = base64.b64encode(f.read()).decode("utf-8")

chapter_1_json = next(
    page
    for page in example_json["data"]
    if page["Title"] == "Chapter 1: The U.S. Constitution"
)

# %%
# Construct the prompt
def construct_prompt(md_instructions, example_json):
    prompt = f"""You are an expert content converter specializing in educational materials. Your task is to convert the provided PDF document into iTELL JSON format.

INSTRUCTIONS:
{md_instructions}

EXAMPLE OUTPUT FORMAT:
```json
{json.dumps(example_json, indent=2)}
```

Please convert the PDF document into iTELL JSON format following the instructions and example provided. Ensure proper chunking, appropriate headers, and maintain the educational structure. Return only valid JSON."""
    return prompt


prompt = construct_prompt(md_instructions, chapter_1_json)
# print(prompt)

# %%
def openai_convert(pdf_b64, prompt):
    completion = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "file",
                        "file": {
                            "filename": pdf_path,
                            "file_data": f"data:application/pdf;base64,{pdf_b64}",
                        },
                    },
                    {
                        "type": "text",
                        "text": prompt,
                    },
                ],
            },
        ],
        max_completion_tokens=4_000,
    )

    return completion.choices[0].message.content.strip()


content = openai_convert(pdf_b64, prompt)
print(content)
# Out:
# {
#   "id": 1000,
#   "documentId": "one-nation-one-people-ch1-4",
#   "Title": "One Nation, One People: Chapters 1\u20134",
#   "Content": [
#     {
#       "__component": "page.chunk",
#       "id": 6000,
#       "Header": "Learning Objectives",
#       "Text": "<section class=\"Callout\"><div><p>In these chapters, you will learn about:</p><ul><li>The U.S. Constitution and its Preamble</li><li>The structure of the federal government (three branches)</li><li>How the Constitution can be changed and the Bill of Rights</li><li>The Legislative, Executive, and Judicial branches and how they function</li></ul></div></section>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6001,
#       "Header": "The U.S. Constitution",
#       "Text": "<p>The U.S. Constitution was written in 1787. It is the oldest written constitution in the world. The Constitution sets up the government and protects the basic rights of people living in the United States.</p><p>The Constitution was written during the Founding Era. In 1787, leaders such as George Washington, Benjamin Franklin, James Madison, and Alexander Hamilton met in Philadelphia, Pennsylvania, at the Constitutional Convention. The leaders who met at the Convention are often called the Founders. The Founders wrote the original Constitution, which included a Preamble and seven sections.</p><p>Since 1787 there have been changes to the Constitution called amendments. There are 27 amendments to the Constitution. The amendments are listed after the seven sections of the original document.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6002,
#       "Header": "The Preamble: We the People",
#       "Text": "<p>The beginning of the Constitution is called the Preamble. The Preamble explains why the Founders wrote the Constitution and states the principle of self-government. Self-government means that the people govern themselves rather than being ruled by a king or queen.</p><p>The idea of self-government is captured in the first three words of the Constitution: \"We the People.\" Under the Constitution, the people elect representatives to serve in local, state, and federal government.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6003,
#       "Header": "The Federal Government Overview",
#       "Text": "<h3>The Three Branches of Government</h3><p>The first three sections of the Constitution establish the U.S. government and describe three branches: the Legislative Branch, the Executive Branch, and the Judicial Branch. Together, these branches form the federal government.</p><ul><li>Legislative Branch: Congress (makes federal laws)</li><li>Executive Branch: President and administration (enforces federal laws)</li><li>Judicial Branch: Supreme Court and other federal courts (reviews federal laws)</li></ul>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6004,
#       "Header": "Separation of Powers",
#       "Text": "<p>To prevent any single person or group from gaining too much power, the Constitution divides government authority among three branches. This principle is called separation of powers. Each branch has different responsibilities and checks on the other branches to stop one branch from becoming too powerful.</p><p>Examples of responsibilities:</p><ul><li>Congress makes federal laws.</li><li>The President enforces federal laws.</li><li>The Judicial Branch reviews and interprets federal laws.</li></ul>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6005,
#       "Header": "Powers of the Federal Government",
#       "Text": "<p>The Constitution lists powers granted to the federal government. Examples include creating and maintaining an army to defend the nation, declaring war when necessary, making treaties with other countries, and printing money. These are national-level powers that apply across all states.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6006,
#       "Header": "State Governments",
#       "Text": "<p>The fourth section of the Constitution explains the role and structure of state governments. Each state has its own government with three branches similar to the federal government: a legislative branch, an executive branch headed by a governor, and a judicial branch.</p><p>State governments are responsible for many services such as public safety (police and fire departments) and education (public schools, state colleges, and universities). To find the current governor of your state, visit the official resource pages such as <a href=\"https://usa.gov/state-governor\" target=\"_blank\" rel=\"noopener noreferrer\">usa.gov/state-governor</a>.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6007,
#       "Header": "Changing the Constitution",
#       "Text": "<p>The process for changing the Constitution is described in the Constitution itself. Changes are called amendments. To add an amendment, it must be approved by three-fourths of the states. With 50 states today, that means 38 states must approve an amendment for it to be added to the Constitution.</p><p>There are currently 27 amendments to the U.S. Constitution.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6008,
#       "Header": "Supreme Law and Rule of Law",
#       "Text": "<p>The Constitution is called the supreme law of the land. This means that no one in the United States is above the Constitution and that all levels of government must follow it.</p><p>The United States supports the rule of law, which means that everyone must follow the law and that laws apply equally to all people and institutions.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6009,
#       "Header": "Approving the Constitution",
#       "Text": "<p>The seventh section of the original Constitution required approval by the states for the document to take effect. When the Constitution was written, there were 13 original states. The Constitution required approval by nine of those states for ratification. New Hampshire became the ninth state in 1788, and all 13 had approved it by 1790.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6010,
#       "Header": "The Bill of Rights and Subsequent Amendments",
#       "Text": "<p>When the Constitution was first written, it did not include a formal list of individual rights. The Founders added the first ten amendments soon after ratification. These first ten amendments are known as the Bill of Rights and enumerate key civil liberties and protections for individuals.</p><p>Later amendments expanded or clarified rights, including who may be a U.S. citizen and who may vote. In total there are 27 amendments to the Constitution.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6011,
#       "Header": "The Legislative Branch (Congress) Overview",
#       "Text": "<p>The Legislative Branch is one part of the federal government and is also called the U.S. Congress. The Constitution designates Congress as the body that makes federal laws.</p><p>To balance representation, the Founders established a bicameral (two-part) Congress: the House of Representatives and the Senate. This structure addressed differing views about representation between large and small states.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6012,
#       "Header": "The House of Representatives",
#       "Text": "<p>The House of Representatives has 435 voting members. Each member represents a congressional district within a state. States with larger populations have more representatives; states with smaller populations have fewer. For example, California has many representatives while less-populated states like Wyoming may have only one.</p><p>Members of the House are elected every two years. To serve, a Representative must be at least 25 years old and live in the state they represent. Only U.S. citizens may run for federal office.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6013,
#       "Header": "The Senate",
#       "Text": "<p>The Senate has 100 U.S. Senators, with each state represented by two senators regardless of population. Senators represent all the people of their state and are elected for six-year terms. To be a Senator, a person must be at least 30 years old and live in the state they represent. As with the House, only U.S. citizens may run for the Senate.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6014,
#       "Header": "How Congress Makes Federal Laws",
#       "Text": "<p>When Congress wants to make a new law, it writes a proposal called a bill. For a bill to become law, it must be approved by a majority in both the House of Representatives and the Senate. For example, a majority of the 435-member House is at least 218 votes. In the Senate, most bills require a majority of the 100 Senators (at least 51 votes).</p><p>After both chambers pass a bill, it is sent to the President. If the President signs the bill, it becomes law. If the President vetoes the bill (refuses to sign it), the bill does not become law unless Congress overrides the veto according to constitutional procedures.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6015,
#       "Header": "The Executive Branch Overview",
#       "Text": "<p>The Executive Branch is the part of government that enforces federal laws. The President is in charge of the Executive Branch. Other key parts of the Executive Branch include the Vice President, the President's Cabinet, and the many executive departments and agencies that carry out government functions.</p><p>The Founders feared too much power in a single executive, so they designed checks and balances and emphasized that the President must also follow the rule of law.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6016,
#       "Header": "The President's Cabinet and Agencies",
#       "Text": "<p>The President's Cabinet consists of the leaders of the major executive departments and other top officials who advise the President. Department leaders are commonly titled \"Secretary\" (for example, the Secretary of State), while the head of the Department of Justice is the Attorney General.</p><p>Executive departments contain many agencies. Examples include the Federal Bureau of Investigation (FBI) in the Department of Justice and U.S. Citizenship and Immigration Services (USCIS) within the Department of Homeland Security.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6017,
#       "Header": "Commander in Chief, Voting, and Vice President",
#       "Text": "<p>The President serves as Commander in Chief of the U.S. Armed Forces, overseeing military leadership and national defense policy. Service in the U.S. Armed Forces is voluntary.</p><p>U.S. citizens vote for President in November, and the President is elected to a four-year term. A person may serve as President for at most two terms. The Constitution requires that a President be at least 35 years old and a U.S. citizen at birth.</p><p>The Vice President serves as an advisor, is part of the Cabinet, and is first in the line of succession. If the President can no longer serve, the Vice President becomes President. If both the President and Vice President cannot serve, the Speaker of the House is next in line.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6018,
#       "Header": "The Judicial Branch Overview",
#       "Text": "<p>The Judicial Branch interprets and reviews federal laws and determines whether those laws follow the Constitution. The Supreme Court and other federal courts make up the Judicial Branch. The Supreme Court is the highest court in the United States and its decisions are final.</p><p>Federal judges are nominated by the President and must be confirmed by the U.S. Senate. The Founders preferred that judges be insulated from politics so they could make decisions based on the Constitution and the rule of law.</p>"
#     },
#     {
#       "__component": "page.chunk",
#       "id": 6019,
#       "Header": "The Supreme Court and Its Justices",
#       "Text": "<p>The Supreme Court typically resolves legal disputes by reviewing cases from lower federal courts. There are nine justices on the Supreme Court. One justice serves as the Chief Justice, who leads the Court in selecting cases to hear, managing courtroom procedures, and steering discussions among the justices.</p><p>When the justices meet and vote, a majority (more than half) determines the Court's decision. For the full and current list of justices and the Chief Justice, consult the Supreme Court's official resources such as <a href=\"https://supremecourt.gov/about/justices.aspx\" target=\"_blank\" rel=\"noopener noreferrer\">supremecourt.gov</a>.</p>"
#     }
#   ]
# }

# %%
# Upload to Strapi...
headers = {
    "Authorization": f"Bearer {strapi_token}",
    "Content-Type": "application/json",
}

upload_response = requests.post(
    f"{strapi_url}/api/contents", json={"data": content}, headers=headers
)

if upload_response.status_code in [200, 201]:
    print("✅ Successfully uploaded to Strapi")
else:
    print(f"❌ Strapi upload failed: {upload_response.status_code}")
